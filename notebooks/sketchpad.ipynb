# %%
import os

# %%
! pwd
# Out:
# /repos/cifar-extended

# %%
os.getcwd()
# Out:
# '/repos/cifar-extended'

# %%
import numpy as np
import scipy as sci
import tensorflow as tf

# %%
DATA_DIR = '/repos/doodle-bot/image/'

# %%
try:
    os.listdir(DATA_DIR)
except:
    print("NOT HERE")
# Out:
# NOT HERE

# %%
labels = [i for i in os.listdir(DATA_DIR) if i[0] != '.']

labels
# Out:
# ['cat',
#  'car',
#  'dog',
#  'truck',
#  'bird',
#  'airplane',
#  'ship',
#  'frog',
#  'horse',
#  'deer']

# %%
file_dict
# Out:
# {'airplane': ['U1215P1T1D13475786F21DT20070718164228.jpg',
#   '3602107575_ab21be03a4.jpg',
#   '2154429300_ef9ea1bceb.jpg',
#   '160993033_9cb36aecec.jpg',
#   '6470689.jpg',
#   '2455319970_3353b0b541.jpg',
#   '07051608565760.jpg',
#   '2455044316_7a60dc6bfc.jpg',
#   '2546978308_dbe4632980.jpg',
#   '3001484897_7d7ea74b3a.jpg',
#   '489765227_0dd28b9dc8.jpg',
#   '2002198357_585adf1007.jpg',
#   'B747-238B-73ebay.jpg',
#   'propellers.jpg',
#   '166520701_5967a9091f.jpg',
#   '2585668183_9f1688c7e2.jpg',
#   '333325487_f2e3af7a5b.jpg',
#   '767tanker.jpg',
#   'An-124-Ruslan.jpg',
#   '2180913809_aaa6eb63c2.jpg',
#   '3057553268_c4192d055e.jpg',
#   '205392662_b251f38ec4.jpg',
#   'Ultralite.jpg',
#   '1552730676_65e5592eab.jpg',
#   '268803345_337a0fdd23.jpg',
#   'MAS7550NE-l.jpg',
#   '39402088_51136d05d6.jpg',
#   '3670798755_4e361aaff5.jpg',
#   '747777cx_1.jpg',
#   '525299872_15866f6ee8.jpg',
#   'gsmiextra.jpg',
#   '3782538943_5aea42b3ef.jpg',
#   '08041718029803.jpg',
# ...

# %%
def get_image_files():
    file_dict = {label: os.listdir(f"{DATA_DIR}{label}/") for label in labels}
    files = []
    for label in labels:
        path = DATA_DIR + f"{label}/"
        for file in os.listdir(path):
            files.append(path + file)
            
    return files

# %%
get_image_files()
# Out:
# ['/repos/doodle-bot/images/cat/1808755986_c7d45730b7.jpg',
#  '/repos/doodle-bot/images/cat/450082418_71a9b8a42e.jpg',
#  '/repos/doodle-bot/images/cat/107473205_18bf5d4560.jpg',
#  '/repos/doodle-bot/images/cat/197997632_da04aaca19.jpg',
#  '/repos/doodle-bot/images/cat/452432138_0c9fefdc1f.jpg',
#  '/repos/doodle-bot/images/cat/2152538865_8afc69e8f8.jpg',
#  '/repos/doodle-bot/images/cat/tiger01.jpg',
#  '/repos/doodle-bot/images/cat/152535490_8ae10ceadd.jpg',
#  '/repos/doodle-bot/images/cat/redsquirrel03.jpg',
#  '/repos/doodle-bot/images/cat/MountainLion.1.PhilHolden.jpg',
#  '/repos/doodle-bot/images/cat/lion_carolyn_gorin_420_420x284.jpg',
#  '/repos/doodle-bot/images/cat/cedar_creek_trophy_catfish_18_small.jpg',
#  '/repos/doodle-bot/images/cat/2219890637_c29141e39b.jpg',
#  '/repos/doodle-bot/images/cat/2111262008_4852f3e19f.jpg',
#  '/repos/doodle-bot/images/cat/806008927_93d7309d3b.jpg',
#  '/repos/doodle-bot/images/cat/2986006437_003b55ab4a.jpg',
# ...
